# %% [markdown]
# """
# Base de datos de usuarios con SQLAlchemy.
# Campos: Nombre, Apellido, Rol, Correo, Contraseña (encriptada), Fecha de creación.
#
# Dividido en procesos:
#   PROCESO 1 — Conexión a la base de datos
#   PROCESO 2 — Definición de la tabla
#   PROCESO 3 — Apertura de la sesión de trabajo
#   PROCESO 4 — Crear usuarios
#   PROCESO 5 — Consultar usuarios
#   PROCESO 6 — Modificar usuarios
#   PROCESO 7 — Eliminar usuarios
# """

# %%
from datetime import datetime
from sqlalchemy import create_engine, Column, Integer, String, DateTime
from sqlalchemy.orm import DeclarativeBase, Session, sessionmaker
from werkzeug.security import generate_password_hash, check_password_hash #(Para la contraseña)

# %%
# Conexión a la base de datos
engine = create_engine("sqlite:///usuarios.db", echo=True)

# %%
# Clase base
class Base(DeclarativeBase):
    pass

# Tu primera tabla
class Usuario(Base):
    __tablename__ = "usuarios"
    
    id = Column(Integer, primary_key=True)
    nombre = Column(String(100), nullable=False)
    apellido = Column(String(100), nullable=False)
    rol = Column(String(50), nullable=False)
    correo = Column(String(150), nullable=False, unique=True)
    contrasena_hash = Column(String(255), nullable=False)
    fecha_creacion = Column(DateTime, default=datetime.utcnow)

# Crear la tabla en la base de datos
Base.metadata.create_all(engine)

print("Tabla creada ✅")
# Out:
# 2026-08-17 20:50:15,053 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-08-17 20:50:15,055 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("usuarios")
# 2026-08-17 20:50:15,057 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-08-17 20:50:15,059 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("usuarios")
# 2026-08-17 20:50:15,060 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2026-08-17 20:50:15,063 INFO sqlalchemy.engine.Engine
# CREATE TABLE usuarios (
# 	id INTEGER NOT NULL,
# 	nombre VARCHAR(100) NOT NULL,
# 	apellido VARCHAR(100) NOT NULL,
# 	rol VARCHAR(50) NOT NULL,
# 	correo VARCHAR(150) NOT NULL,
# 	contrasena_hash VARCHAR(255) NOT NULL,
# 	fecha_creacion DATETIME,
# 	PRIMARY KEY (id),
# 	UNIQUE (correo)
# )
#
#
# 2026-08-17 20:50:15,064 INFO sqlalchemy.engine.Engine [no key 0.00142s] ()
# 2026-08-17 20:50:15,082 INFO sqlalchemy.engine.Engine COMMIT
# Tabla creada ✅

# %%
# Crear una sesión
with Session(engine) as session:
    
    # Crear un usuario nuevo
    nuevo_usuario = Usuario(
        nombre="Prueba2",
        apellido="Prueba2",
        rol="admin",
        correo="prueba2@email.com",
        contrasena_hash="Contra123"
    )
    
    # Agregar y guardar
    session.add(nuevo_usuario)
    session.commit()
    
    print("Usuario creado ✅")
# Out:
# 2026-08-17 20:51:38,339 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-08-17 20:51:38,341 INFO sqlalchemy.engine.Engine INSERT INTO usuarios (nombre, apellido, rol, correo, contrasena_hash, fecha_creacion) VALUES (?, ?, ?, ?, ?, ?)
# 2026-08-17 20:51:38,342 INFO sqlalchemy.engine.Engine [cached since 75.08s ago] ('Prueba2', 'Prueba2', 'admin', 'prueba2@email.com', 'Contra123', '2026-08-18 01:51:38.341768')
# 2026-08-17 20:51:38,346 INFO sqlalchemy.engine.Engine COMMIT
# Usuario creado ✅

# %%
# Consultar usuarios
with Session(engine) as session:
    usuarios = session.query(Usuario).all()
    for usuario in usuarios:
        print(f"ID: {usuario.id}")
        print(f"Nombre: {usuario.nombre}")
        print(f"Apellido: {usuario.apellido}")
        print(f"Correo: {usuario.correo}")
        print(f"Rol: {usuario.rol}")
        print(f"Fecha: {usuario.fecha_creacion}")
        print("---")
# Out:
# 2026-08-17 20:51:43,761 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-08-17 20:51:43,763 INFO sqlalchemy.engine.Engine SELECT usuarios.id AS usuarios_id, usuarios.nombre AS usuarios_nombre, usuarios.apellido AS usuarios_apellido, usuarios.rol AS usuarios_rol, usuarios.correo AS usuarios_correo, usuarios.contrasena_hash AS usuarios_contrasena_hash, usuarios.fecha_creacion AS usuarios_fecha_creacion
# FROM usuarios
# 2026-08-17 20:51:43,764 INFO sqlalchemy.engine.Engine [cached since 46.31s ago] ()
# ID: 1
# Nombre: Prueba
# Apellido: Prueba
# Correo: prueba@email.com
# Rol: admin
# Fecha: 2026-08-18 01:50:23.261704
# ---
# ID: 2
# Nombre: Prueba2
# Apellido: Prueba2
# Correo: prueba2@email.com
# Rol: admin
# Fecha: 2026-08-18 01:51:38.341768
# ---
# 2026-08-17 20:51:43,767 INFO sqlalchemy.engine.Engine ROLLBACK
